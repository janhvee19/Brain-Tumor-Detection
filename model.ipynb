# %%
import os
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import warnings
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       4 import pandas as pd
#       5 import matplotlib.pyplot as plt
# ----> 6 import seaborn as sns
#       7 from glob import glob
#       8 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
def train_df(tr_path):
    classes, class_paths = zip(*[(label, os.path.join(tr_path, label, image))
                                 for label in os.listdir(tr_path) if os.path.isdir(os.path.join(tr_path, label))
                                 for image in os.listdir(os.path.join(tr_path, label))])

    tr_df = pd.DataFrame({'Class Path': class_paths, 'Class': classes})
    return tr_df

# %%
def test_df(ts_path):
    classes, class_paths = zip(*[(label, os.path.join(ts_path, label, image))
                                 for label in os.listdir(ts_path) if os.path.isdir(os.path.join(ts_path, label))
                                 for image in os.listdir(os.path.join(ts_path, label))])

    ts_df = pd.DataFrame({'Class Path': class_paths, 'Class': classes})
    return ts_df

# %%
dataset_path = 'archive (2)/Training'  # Using relative path
tr_df = train_df(dataset_path)

# %%
tr_df

# %%
dataset_path1 = 'archive (2)/Testing'  # Using relative path
ts_df = test_df(dataset_path1)

# %%
ts_df

# %%
plt.figure(figsize=(15,7))
ax = sns.countplot(data=tr_df , y=tr_df['Class'])

plt.xlabel('')
plt.ylabel('')
plt.title('Count of images in each class', fontsize=20)
ax.bar_label(ax.containers[0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 plt.figure(figsize=(15,7))
# ----> 2 ax = sns.countplot(data=tr_df , y=tr_df['Class'])
#       4 plt.xlabel('')
#       5 plt.ylabel('')
#
# NameError: name 'sns' is not defined

# %%
#Count each class in test data
plt.figure(figsize=(15, 7))
ax = sns.countplot(y=ts_df['Class'], palette='viridis')

ax.set(xlabel='', ylabel='', title='Count of images in each class')
ax.bar_label(ax.containers[0])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 #Count each class in test data
#       2 plt.figure(figsize=(15, 7))
# ----> 3 ax = sns.countplot(y=ts_df['Class'], palette='viridis')
#       5 ax.set(xlabel='', ylabel='', title='Count of images in each class')
#       6 ax.bar_label(ax.containers[0])
#
# NameError: name 'sns' is not defined

# %%
valid_df, ts_df = train_test_split(ts_df, train_size=0.5, random_state=20, stratify=ts_df['Class'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 valid_df, ts_df = train_test_split(ts_df, train_size=0.5, random_state=20, stratify=ts_df['Class'])
#
# NameError: name 'train_test_split' is not defined

# %%
valid_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 valid_df
#
# NameError: name 'valid_df' is not defined

# %%
batch_size = 32
img_size = (299, 299)

_gen = ImageDataGenerator(rescale=1/255,
                          brightness_range=(0.8, 1.2))

ts_gen = ImageDataGenerator(rescale=1/255)


tr_gen = _gen.flow_from_dataframe(tr_df, x_col='Class Path',
                                  y_col='Class', batch_size=batch_size,
                                  target_size=img_size)

valid_gen = _gen.flow_from_dataframe(valid_df, x_col='Class Path',
                                     y_col='Class', batch_size=batch_size,
                                     target_size=img_size)

ts_gen = ts_gen.flow_from_dataframe(ts_df, x_col='Class Path',
                                  y_col='Class', batch_size=16,
                                  target_size=img_size, shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 batch_size = 32
#       2 img_size = (299, 299)
# ----> 4 _gen = ImageDataGenerator(rescale=1/255,
#       5                           brightness_range=(0.8, 1.2))
#       7 ts_gen = ImageDataGenerator(rescale=1/255)
#      10 tr_gen = _gen.flow_from_dataframe(tr_df, x_col='Class Path',
#      11                                   y_col='Class', batch_size=batch_size,
#      12                                   target_size=img_size)
#
# NameError: name 'ImageDataGenerator' is not defined

# %%
class_dict = tr_gen.class_indices
classes = list(class_dict.keys())
images, labels = next(ts_gen)

plt.figure(figsize=(20, 20))

for i, (image, label) in enumerate(zip(images, labels)):
    plt.subplot(4,4, i + 1)
    plt.imshow(image)
    class_name = classes[np.argmax(label)]
    plt.title(class_name, color='k', fontsize=15)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 class_dict = tr_gen.class_indices
#       2 classes = list(class_dict.keys())
#       3 images, labels = next(ts_gen)
#
# NameError: name 'tr_gen' is not defined

# %%
img_shape=(299,299,3)
base_model = tf.keras.applications.Xception(include_top= False, weights= "imagenet",
                            input_shape= img_shape, pooling= 'max')

# for layer in base_model.layers:
#     layer.trainable = False
    
model = Sequential([
    base_model,
    Flatten(),
    Dropout(rate= 0.3),
    Dense(128, activation= 'relu'),
    Dropout(rate= 0.25),
    Dense(4, activation= 'softmax')
])

model.compile(Adamax(learning_rate= 0.001),
              loss= 'categorical_crossentropy',
              metrics= ['accuracy',
                        Precision(),
                        Recall()])

model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 img_shape=(299,299,3)
# ----> 2 base_model = tf.keras.applications.Xception(include_top= False, weights= "imagenet",
#       3                             input_shape= img_shape, pooling= 'max')
#       5 # for layer in base_model.layers:
#       6 #     layer.trainable = False
#       8 model = Sequential([
#       9     base_model,
#      10     Flatten(),
#    (...)     14     Dense(4, activation= 'softmax')
#      15 ])
#
# NameError: name 'tf' is not defined

# %%
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 tf.keras.utils.plot_model(model, show_shapes=True)
#
# NameError: name 'tf' is not defined

# %%
hist = model.fit(tr_gen,
                 epochs=10,
                 validation_data=valid_gen,
                 shuffle= False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 hist = model.fit(tr_gen,
#       2                  epochs=10,
#       3                  validation_data=valid_gen,
#       4                  shuffle= False)
#
# NameError: name 'model' is not defined

# %%
hist.history.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 hist.history.keys()
#
# NameError: name 'hist' is not defined

# %%
tr_acc = hist.history['accuracy']
tr_loss = hist.history['loss']
tr_per = hist.history['precision']
tr_recall = hist.history['recall']
val_acc = hist.history['val_accuracy']
val_loss = hist.history['val_loss']
val_per = hist.history['val_precision']
val_recall = hist.history['val_recall']

index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
index_precision = np.argmax(val_per)
per_highest = val_per[index_precision]
index_recall = np.argmax(val_recall)
recall_highest = val_recall[index_recall]

Epochs = [i + 1 for i in range(len(tr_acc))]
loss_label = f'Best epoch = {str(index_loss + 1)}'
acc_label = f'Best epoch = {str(index_acc + 1)}'
per_label = f'Best epoch = {str(index_precision + 1)}'
recall_label = f'Best epoch = {str(index_recall + 1)}'
plt.figure(figsize=(20, 12))
plt.style.use('fivethirtyeight')


plt.subplot(2, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label='Training loss')
plt.plot(Epochs, val_loss, 'g', label='Validation loss')
plt.scatter(index_loss + 1, val_lowest, s=150, c='blue', label=loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label='Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label='Validation Accuracy')
plt.scatter(index_acc + 1, acc_highest, s=150, c='blue', label=acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.subplot(2, 2, 3)
plt.plot(Epochs, tr_per, 'r', label='Precision')
plt.plot(Epochs, val_per, 'g', label='Validation Precision')
plt.scatter(index_precision + 1, per_highest, s=150, c='blue', label=per_label)
plt.title('Precision and Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(Epochs, tr_recall, 'r', label='Recall')
plt.plot(Epochs, val_recall, 'g', label='Validation Recall')
plt.scatter(index_recall + 1, recall_highest, s=150, c='blue', label=recall_label)
plt.title('Recall and Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.grid(True)

plt.suptitle('Model Training Metrics Over Epochs', fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 tr_acc = hist.history['accuracy']
#       2 tr_loss = hist.history['loss']
#       3 tr_per = hist.history['precision']
#
# NameError: name 'hist' is not defined

# %%
train_score = model.evaluate(tr_gen, verbose=1)
valid_score = model.evaluate(valid_gen, verbose=1)
test_score = model.evaluate(ts_gen, verbose=1)

print(f"Train Loss: {train_score[0]:.4f}")
print(f"Train Accuracy: {train_score[1]*100:.2f}%")
print(f"Validation Loss: {valid_score[0]:.4f}")
print(f"Validation Accuracy: {valid_score[1]*100:.2f}%")
print(f"Test Loss: {test_score[0]:.4f}")
print(f"Test Accuracy: {test_score[1]*100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 train_score = model.evaluate(tr_gen, verbose=1)
#       2 valid_score = model.evaluate(valid_gen, verbose=1)
#       3 test_score = model.evaluate(ts_gen, verbose=1)
#
# NameError: name 'model' is not defined

# %%
preds = model.predict(ts_gen)
y_pred = np.argmax(preds, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 preds = model.predict(ts_gen)
#       2 y_pred = np.argmax(preds, axis=1)
#
# NameError: name 'model' is not defined

# %%
cm = confusion_matrix(ts_gen.classes, y_pred)
labels = list(class_dict.keys())
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label')
plt.ylabel('Truth Label')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 cm = confusion_matrix(ts_gen.classes, y_pred)
#       2 labels = list(class_dict.keys())
#       3 plt.figure(figsize=(10,8))
#
# NameError: name 'confusion_matrix' is not defined

# %%
clr = classification_report(ts_gen.classes, y_pred)
print(clr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 clr = classification_report(ts_gen.classes, y_pred)
#       2 print(clr)
#
# NameError: name 'classification_report' is not defined

# %%
def predict(img_path):
    import numpy as np
    import matplotlib.pyplot as plt
    from PIL import Image
    # Explicitly define labels in the correct order (0, 1, 2, 3)
    labels = ['glioma', 'meningioma', 'notumor', 'pituitary']
    
    plt.figure(figsize=(12, 12))
    img = Image.open(img_path)
    # Ensure image is RGB (3 channels)
    if img.mode != 'RGB':
        img = img.convert('RGB')
    resized_img = img.resize((299, 299))
    img = np.asarray(resized_img)
    img = np.expand_dims(img, axis=0)
    img = img / 255
    predictions = model.predict(img)
    probs = list(predictions[0])
    
    plt.subplot(2, 1, 1)
    plt.imshow(resized_img)
    plt.subplot(2, 1, 2)
    bars = plt.barh(labels, probs)
    plt.xlabel('Probability', fontsize=15)
    ax = plt.gca()
    ax.bar_label(bars, fmt = '%.2f')
    plt.show()

# %%
model.save('brain_tumor_model.keras')
print('Model saved successfully as brain_tumor_model.keras')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 model.save('brain_tumor_model.keras')
#       2 print('Model saved successfully as brain_tumor_model.keras')
#
# NameError: name 'model' is not defined

# %%
import os
import random

# Define the testing directory
test_dir = 'archive (2)/Testing'

# Get a list of all image files
all_test_images = []
for root, dirs, files in os.walk(test_dir):
    for file in files:
        if file.endswith('.jpg'):
            all_test_images.append(os.path.join(root, file))

# Pick a random image
if all_test_images:
    random_image_path = random.choice(all_test_images)
    print(f"Testing with image: {random_image_path}")
    
    # Extract actual class from path for comparison
    actual_class = os.path.basename(os.path.dirname(random_image_path))
    print(f"Actual Class: {actual_class}")
    
    # Run prediction
    predict(random_image_path)
else:
    print("No images found in the testing directory.")
# Out:
# Testing with image: archive (2)/Testing\notumor\Te-no_0055.jpg
# Actual Class: notumor
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 24
#      21     print(f"Actual Class: {actual_class}")
#      23     # Run prediction
# ---> 24     predict(random_image_path)
#      25 else:
#      26     print("No images found in the testing directory.")
#
# Cell In[17], line 17, in predict(img_path)
#      15 img = np.expand_dims(img, axis=0)
#      16 img = img / 255
# ---> 17 predictions = model.predict(img)
#      18 probs = list(predictions[0])
#      20 plt.subplot(2, 1, 1)
#
# NameError: name 'model' is not defined
