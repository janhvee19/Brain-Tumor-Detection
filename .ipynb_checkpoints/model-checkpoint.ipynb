# %%
import os
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import warnings
warnings.filterwarnings("ignore")

# %%
def train_df(tr_path):
    classes, class_paths = zip(*[(label, os.path.join(tr_path, label, image))
                                 for label in os.listdir(tr_path) if os.path.isdir(os.path.join(tr_path, label))
                                 for image in os.listdir(os.path.join(tr_path, label))])

    tr_df = pd.DataFrame({'Class Path': class_paths, 'Class': classes})
    return tr_df

# %%
def test_df(ts_path):
    classes, class_paths = zip(*[(label, os.path.join(ts_path, label, image))
                                 for label in os.listdir(ts_path) if os.path.isdir(os.path.join(ts_path, label))
                                 for image in os.listdir(os.path.join(ts_path, label))])

    ts_df = pd.DataFrame({'Class Path': class_paths, 'Class': classes})
    return ts_df

# %%
dataset_path = 'archive (2)/Training'  # Using relative path
tr_df = train_df(dataset_path)

# %%
tr_df
# Out:
#                                           Class Path       Class
# 0      archive (2)/Training/pituitary/Tr-pi_0505.jpg   pituitary
# 1      archive (2)/Training/pituitary/Tr-pi_0263.jpg   pituitary
# 2      archive (2)/Training/pituitary/Tr-pi_0277.jpg   pituitary
# 3      archive (2)/Training/pituitary/Tr-pi_1169.jpg   pituitary
# 4      archive (2)/Training/pituitary/Tr-pi_0511.jpg   pituitary
# ...                                              ...         ...
# 5707  archive (2)/Training/meningioma/Tr-me_1053.jpg  meningioma
# 5708  archive (2)/Training/meningioma/Tr-me_0403.jpg  meningioma
# 5709  archive (2)/Training/meningioma/Tr-me_0365.jpg  meningioma
# 5710  archive (2)/Training/meningioma/Tr-me_0371.jpg  meningioma
# 5711  archive (2)/Training/meningioma/Tr-me_0417.jpg  meningioma
#
# [5712 rows x 2 columns]

# %%
dataset_path1 = 'archive (2)/Testing'  # Using relative path
ts_df = test_df(dataset_path1)

# %%
ts_df
# Out:
#                                            Class Path       Class
# 0        archive (2)/Testing/pituitary/Te-pi_0233.jpg   pituitary
# 1        archive (2)/Testing/pituitary/Te-pi_0227.jpg   pituitary
# 2        archive (2)/Testing/pituitary/Te-pi_0019.jpg   pituitary
# 3        archive (2)/Testing/pituitary/Te-pi_0031.jpg   pituitary
# 4        archive (2)/Testing/pituitary/Te-pi_0025.jpg   pituitary
# ...                                               ...         ...
# 1306    archive (2)/Testing/meningioma/Te-me_0080.jpg  meningioma
# 1307    archive (2)/Testing/meningioma/Te-me_0094.jpg  meningioma
# 1308    archive (2)/Testing/meningioma/Te-me_0137.jpg  meningioma
# 1309    archive (2)/Testing/meningioma/Te-me_0123.jpg  meningioma
# 1310  archive (2)/Testing/meningioma/Te-meTr_0009.jpg  meningioma
#
# [1311 rows x 2 columns]

# %%
plt.figure(figsize=(15,7))
ax = sns.countplot(data=tr_df , y=tr_df['Class'])

plt.xlabel('')
plt.ylabel('')
plt.title('Count of images in each class', fontsize=20)
ax.bar_label(ax.containers[0])
plt.show()

# %%
#Count each class in test data
plt.figure(figsize=(15, 7))
ax = sns.countplot(y=ts_df['Class'], palette='viridis')

ax.set(xlabel='', ylabel='', title='Count of images in each class')
ax.bar_label(ax.containers[0])

plt.show()

# %%
valid_df, ts_df = train_test_split(ts_df, train_size=0.5, random_state=20, stratify=ts_df['Class'])

# %%
valid_df
# Out:
#                                          Class Path       Class
# 991       archive (2)/Testing/glioma/Te-gl_0129.jpg      glioma
# 1023  archive (2)/Testing/meningioma/Te-me_0107.jpg  meningioma
# 61     archive (2)/Testing/pituitary/Te-pi_0197.jpg   pituitary
# 1078  archive (2)/Testing/meningioma/Te-me_0274.jpg  meningioma
# 814       archive (2)/Testing/glioma/Te-gl_0219.jpg      glioma
# ...                                             ...         ...
# 764       archive (2)/Testing/glioma/Te-gl_0136.jpg      glioma
# 554      archive (2)/Testing/notumor/Te-no_0206.jpg     notumor
# 978     archive (2)/Testing/glioma/Te-glTr_0004.jpg      glioma
# 1199  archive (2)/Testing/meningioma/Te-me_0182.jpg  meningioma
# 626      archive (2)/Testing/notumor/Te-no_0139.jpg     notumor
#
# [655 rows x 2 columns]

# %%
batch_size = 32
img_size = (299, 299)

_gen = ImageDataGenerator(rescale=1/255,
                          brightness_range=(0.8, 1.2))

ts_gen = ImageDataGenerator(rescale=1/255)


tr_gen = _gen.flow_from_dataframe(tr_df, x_col='Class Path',
                                  y_col='Class', batch_size=batch_size,
                                  target_size=img_size)

valid_gen = _gen.flow_from_dataframe(valid_df, x_col='Class Path',
                                     y_col='Class', batch_size=batch_size,
                                     target_size=img_size)

ts_gen = ts_gen.flow_from_dataframe(ts_df, x_col='Class Path',
                                  y_col='Class', batch_size=16,
                                  target_size=img_size, shuffle=False)
# Out:
# Found 5712 validated image filenames belonging to 4 classes.
# Found 655 validated image filenames belonging to 4 classes.
# Found 656 validated image filenames belonging to 4 classes.

# %%
class_dict = tr_gen.class_indices
classes = list(class_dict.keys())
images, labels = next(ts_gen)

plt.figure(figsize=(20, 20))

for i, (image, label) in enumerate(zip(images, labels)):
    plt.subplot(4,4, i + 1)
    plt.imshow(image)
    class_name = classes[np.argmax(label)]
    plt.title(class_name, color='k', fontsize=15)

plt.show()

# %%
img_shape=(299,299,3)
base_model = tf.keras.applications.Xception(include_top= False, weights= "imagenet",
                            input_shape= img_shape, pooling= 'max')

# for layer in base_model.layers:
#     layer.trainable = False
    
model = Sequential([
    base_model,
    Flatten(),
    Dropout(rate= 0.3),
    Dense(128, activation= 'relu'),
    Dropout(rate= 0.25),
    Dense(4, activation= 'softmax')
])

model.compile(Adamax(learning_rate= 0.001),
              loss= 'categorical_crossentropy',
              metrics= ['accuracy',
                        Precision(),
                        Recall()])

model.summary()
# Out:
# 2025-11-25 22:29:39.709137: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3
# 2025-11-25 22:29:39.709160: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-11-25 22:29:39.709164: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2025-11-25 22:29:39.709179: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-11-25 22:29:39.709187: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ xception (Functional)           │ (None, 2048)           │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,124,268 (80.58 MB)
#  Trainable params: 21,069,740 (80.37 MB)
#  Non-trainable params: 54,528 (213.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
hist = model.fit(tr_gen,
                 epochs=10,
                 validation_data=valid_gen,
                 shuffle= False)
# Out:
# Epoch 1/10
# 2025-11-25 22:29:44.669616: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2025-11-25 22:29:44.708581: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3686 - loss: 1.3427 - precision: 0.6733 - recall: 0.1258
# 2025-11-25 22:39:37.048716: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 614s 3s/step - accuracy: 0.5476 - loss: 0.9576 - precision: 0.8806 - recall: 0.3718 - val_accuracy: 0.8076 - val_loss: 0.5328 - val_precision: 0.9356 - val_recall: 0.6656
# Epoch 2/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 801s 4s/step - accuracy: 0.9398 - loss: 0.1757 - precision: 0.9472 - recall: 0.9319 - val_accuracy: 0.9115 - val_loss: 0.2163 - val_precision: 0.9387 - val_recall: 0.8885
# Epoch 3/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 739s 4s/step - accuracy: 0.9806 - loss: 0.0582 - precision: 0.9824 - recall: 0.9788 - val_accuracy: 0.9664 - val_loss: 0.1326 - val_precision: 0.9664 - val_recall: 0.9649
# Epoch 4/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 578s 3s/step - accuracy: 0.9919 - loss: 0.0254 - precision: 0.9928 - recall: 0.9914 - val_accuracy: 0.9847 - val_loss: 0.0676 - val_precision: 0.9847 - val_recall: 0.9847
# Epoch 5/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 600s 3s/step - accuracy: 0.9930 - loss: 0.0253 - precision: 0.9935 - recall: 0.9930 - val_accuracy: 0.9679 - val_loss: 0.1278 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 6/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 559s 3s/step - accuracy: 0.9958 - loss: 0.0134 - precision: 0.9961 - recall: 0.9956 - val_accuracy: 0.9802 - val_loss: 0.0721 - val_precision: 0.9802 - val_recall: 0.9802
# Epoch 7/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 595s 3s/step - accuracy: 0.9977 - loss: 0.0100 - precision: 0.9977 - recall: 0.9977 - val_accuracy: 0.9878 - val_loss: 0.0650 - val_precision: 0.9878 - val_recall: 0.9878
# Epoch 8/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 628s 4s/step - accuracy: 0.9988 - loss: 0.0042 - precision: 0.9991 - recall: 0.9988 - val_accuracy: 0.9832 - val_loss: 0.0809 - val_precision: 0.9847 - val_recall: 0.9817
# Epoch 9/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 621s 3s/step - accuracy: 0.9954 - loss: 0.0162 - precision: 0.9954 - recall: 0.9953 - val_accuracy: 0.9817 - val_loss: 0.0786 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 10/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 593s 3s/step - accuracy: 0.9965 - loss: 0.0137 - precision: 0.9965 - recall: 0.9961 - val_accuracy: 0.9817 - val_loss: 0.0706 - val_precision: 0.9817 - val_recall: 0.9817

# %%
hist.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'precision', 'recall', 'val_accuracy', 'val_loss', 'val_precision', 'val_recall'])

# %%
tr_acc = hist.history['accuracy']
tr_loss = hist.history['loss']
tr_per = hist.history['precision']
tr_recall = hist.history['recall']
val_acc = hist.history['val_accuracy']
val_loss = hist.history['val_loss']
val_per = hist.history['val_precision']
val_recall = hist.history['val_recall']

index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
index_precision = np.argmax(val_per)
per_highest = val_per[index_precision]
index_recall = np.argmax(val_recall)
recall_highest = val_recall[index_recall]

Epochs = [i + 1 for i in range(len(tr_acc))]
loss_label = f'Best epoch = {str(index_loss + 1)}'
acc_label = f'Best epoch = {str(index_acc + 1)}'
per_label = f'Best epoch = {str(index_precision + 1)}'
recall_label = f'Best epoch = {str(index_recall + 1)}'
plt.figure(figsize=(20, 12))
plt.style.use('fivethirtyeight')


plt.subplot(2, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label='Training loss')
plt.plot(Epochs, val_loss, 'g', label='Validation loss')
plt.scatter(index_loss + 1, val_lowest, s=150, c='blue', label=loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label='Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label='Validation Accuracy')
plt.scatter(index_acc + 1, acc_highest, s=150, c='blue', label=acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.subplot(2, 2, 3)
plt.plot(Epochs, tr_per, 'r', label='Precision')
plt.plot(Epochs, val_per, 'g', label='Validation Precision')
plt.scatter(index_precision + 1, per_highest, s=150, c='blue', label=per_label)
plt.title('Precision and Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(Epochs, tr_recall, 'r', label='Recall')
plt.plot(Epochs, val_recall, 'g', label='Validation Recall')
plt.scatter(index_recall + 1, recall_highest, s=150, c='blue', label=recall_label)
plt.title('Recall and Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.grid(True)

plt.suptitle('Model Training Metrics Over Epochs', fontsize=16)
plt.show()

# %%
train_score = model.evaluate(tr_gen, verbose=1)
valid_score = model.evaluate(valid_gen, verbose=1)
test_score = model.evaluate(ts_gen, verbose=1)

print(f"Train Loss: {train_score[0]:.4f}")
print(f"Train Accuracy: {train_score[1]*100:.2f}%")
print(f"Validation Loss: {valid_score[0]:.4f}")
print(f"Validation Accuracy: {valid_score[1]*100:.2f}%")
print(f"Test Loss: {test_score[0]:.4f}")
print(f"Test Accuracy: {test_score[1]*100:.2f}%")
# Out:
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 107s 594ms/step - accuracy: 1.0000 - loss: 5.8285e-04 - precision: 1.0000 - recall: 1.0000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 598ms/step - accuracy: 0.9817 - loss: 0.0650 - precision: 0.9817 - recall: 0.9817
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.9970 - loss: 0.0068 - precision: 0.9985 - recall: 0.9970
# Train Loss: 0.0006
# Train Accuracy: 100.00%
# Validation Loss: 0.0650
# Validation Accuracy: 98.17%
# Test Loss: 0.0068
# Test Accuracy: 99.70%

# %%
preds = model.predict(ts_gen)
y_pred = np.argmax(preds, axis=1)
# Out:
# 2025-11-26 00:21:12.385428: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 14s 306ms/step

# %%
cm = confusion_matrix(ts_gen.classes, y_pred)
labels = list(class_dict.keys())
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label')
plt.ylabel('Truth Label')
plt.show()

# %%
clr = classification_report(ts_gen.classes, y_pred)
print(clr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       150
#            1       0.99      1.00      0.99       153
#            2       1.00      1.00      1.00       203
#            3       1.00      0.99      1.00       150
#
#     accuracy                           1.00       656
#    macro avg       1.00      1.00      1.00       656
# weighted avg       1.00      1.00      1.00       656

# %%
def predict(img_path):
    import numpy as np
    import matplotlib.pyplot as plt
    from PIL import Image
    # Explicitly define labels in the correct order (0, 1, 2, 3)
    labels = ['glioma', 'meningioma', 'notumor', 'pituitary']
    
    plt.figure(figsize=(12, 12))
    img = Image.open(img_path)
    # Ensure image is RGB (3 channels)
    if img.mode != 'RGB':
        img = img.convert('RGB')
    resized_img = img.resize((299, 299))
    img = np.asarray(resized_img)
    img = np.expand_dims(img, axis=0)
    img = img / 255
    predictions = model.predict(img)
    probs = list(predictions[0])
    
    plt.subplot(2, 1, 1)
    plt.imshow(resized_img)
    plt.subplot(2, 1, 2)
    bars = plt.barh(labels, probs)
    plt.xlabel('Probability', fontsize=15)
    ax = plt.gca()
    ax.bar_label(bars, fmt = '%.2f')
    plt.show()

# %%
model.save('brain_tumor_model.keras')
print('Model saved successfully as brain_tumor_model.keras')
# Out:
# Model saved successfully as brain_tumor_model.keras

# %%
import os
import random

# Define the testing directory
test_dir = 'archive (2)/Testing'

# Get a list of all image files
all_test_images = []
for root, dirs, files in os.walk(test_dir):
    for file in files:
        if file.endswith('.jpg'):
            all_test_images.append(os.path.join(root, file))

# Pick a random image
if all_test_images:
    random_image_path = random.choice(all_test_images)
    print(f"Testing with image: {random_image_path}")
    
    # Extract actual class from path for comparison
    actual_class = os.path.basename(os.path.dirname(random_image_path))
    print(f"Actual Class: {actual_class}")
    
    # Run prediction
    predict(random_image_path)
else:
    print("No images found in the testing directory.")
# Out:
# Testing with image: archive (2)/Testing/glioma/Te-gl_0091.jpg
# Actual Class: glioma
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 24
#      21     print(f"Actual Class: {actual_class}")
#      23     # Run prediction
# ---> 24     predict(random_image_path)
#      25 else:
#      26     print("No images found in the testing directory.")
#
# NameError: name 'predict' is not defined
